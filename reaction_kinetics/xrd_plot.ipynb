# %% [markdown]
# ## Plot BBO result

# %% [markdown]
# ## Plt weight fraction result

# %%
import matplotlib.pyplot as plt
import numpy as np
import scienceplots
plt.style.use(['science','ieee'])
# New Data

time_10N_speed1 = np.array([15, 30, 45, 60, 90, 120, 150, 180])
CsBr_10N_speed1 = np.array([0.34809, 0.35338, 0.34396, 0.33011, 0.27098, 0.22476, 0.18409, 0.13255])
PbBr2_10N_speed1 = np.array([0.5835, 0.57573, 0.57469, 0.50982, 0.44917, 0.39939, 0.36767, 0.35355])
CsPbBr3_10N_speed1 = np.array([ 0.05776,0.05486, 0.06073, 0.06052, 0.05187, 0.05948, 0.06172, 0.04372])
Cs4PbBr6_10N_speed1 = np.array([ 0.01065, 0.01603, 0.02063, 0.09955, 0.22798, 0.31638, 0.38653, 0.47019])

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(time_10N_speed1, CsBr_10N_speed1, marker='o', label='CsBr')
plt.plot(time_10N_speed1, PbBr2_10N_speed1, marker='o', label='PbBr2')
plt.plot(time_10N_speed1, CsPbBr3_10N_speed1, marker='o', label='CsPbBr3')
plt.plot(time_10N_speed1, Cs4PbBr6_10N_speed1, marker='o', label='Cs4PbBr6')

# Adding labels and title
plt.xlabel('Reaction Time (min)', fontsize=14)
plt.ylabel('Weight Fraction', fontsize=14)
plt.legend()
# plt.grid(True)
plt.savefig('result2_v=1_10N.png', dpi=300)
plt.show()

# %%
# New Data

time_10N_speed05 = np.array([15,30, 45, 60, 90, 120, 150, 180])
CsBr_10N_speed05 = np.array([0.456, 0.3654, 0.35223, 0.33144, 0.31307, 0.29416, 0.27168, 0.20297])
PbBr2_10N_speed05 = np.array([ 0.533,0.59055, 0.5206, 0.52078, 0.47939, 0.41851, 0.37875, 0.29906])
CsPbBr3_10N_speed05 = np.array([0.01,0.04173, 0.07519, 0.11927, 0.13962, 0.17238, 0.20518, 0.30427])
Cs4PbBr6_10N_speed05 = np.array([0.001,0.00232, 0.05198, 0.02851, 0.06791, 0.11495, 0.14439, 0.1937])

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(time_10N_speed05, CsBr_10N_speed05, marker='o', label='CsBr')
plt.plot(time_10N_speed05, PbBr2_10N_speed05, marker='o', label='PbBr2')
plt.plot(time_10N_speed05, CsPbBr3_10N_speed05, marker='o', label='CsPbBr3')
plt.plot(time_10N_speed05, Cs4PbBr6_10N_speed05, marker='o', label='Cs4PbBr6')

# Adding labels and title
plt.xlabel('Reaction Time (min)',fontsize=14)
plt.ylabel('Weight Fraction',fontsize=14)
plt.legend()
# plt.grid(True)
plt.savefig('result2_v=0.5_10N.png', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
  
time_20N_speed05 = [15,30, 45, 60, 90,120,  150,180]
CsBr_20N_speed05 = [0.39949,0.318, 0.25994, 0.16403, 0.08481,  0.025,0.01029,0.001]
PbBr2_20N_speed05 = [0.52054,0.54742, 0.48434, 0.44501, 0.40855,  0.335,0.3423,0.297]
CsPbBr3_20N_speed05 = [0.02746,0.04426, 0.06049, 0.072, 0.08075,  0.123,0.19557,0.294]
Cs4PbBr6_20N_speed05 = [0.05251,0.09033, 0.19524, 0.31896, 0.42589, 0.517, 0.45184,0.409]

# Error bars
CsBr_err = [0.01174, 0.00607, 0.00415, 0.00357,  0.00261,]
PbBr2_err = [0.0207, 0.01092, 0.00964, 0.00761,  0.0078,]
CsPbBr3_err = [0.00268, 0.00231, 0.00282, 0.00282,  0.00532,]
Cs4PbBr6_err = [0.00406, 0.00349, 0.00663, 0.00601,  0.00847,]

plt.figure(figsize=(10, 6))

plt.plot(time_20N_speed05, CsBr_20N_speed05,  marker='o', label='CsBr')
plt.plot(time_20N_speed05, PbBr2_20N_speed05,  marker='o', label='PbBr2')
plt.plot(time_20N_speed05, CsPbBr3_20N_speed05,  marker='o', label='CsPbBr3')
plt.plot(time_20N_speed05, Cs4PbBr6_20N_speed05,  marker='o', label='Cs4PbBr6')

plt.xlabel('Time (min)', fontsize=14)
plt.ylabel('Weight Fraction', fontsize=14)
plt.legend()
# plt.grid(True)
plt.savefig('result3_v=0.5_20N.png', dpi=300)

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# グラフの作成
time = np.array([30, 45, 60, 90, 120, 150, 180])

fig, axs = plt.subplots(1, 3, figsize=(15, 5))  # 1行3列のサブプロット

# First subplot
axs[2].plot(time, CsBr_10N_speed1[1:], marker='o', label='CsBr')
axs[2].plot(time, PbBr2_10N_speed1[1:], marker='o', label='PbBr2')
axs[2].plot(time, CsPbBr3_10N_speed1[1:], marker='o', label='CsPbBr3')
axs[2].plot(time, Cs4PbBr6_10N_speed1[1:], marker='o', label='Cs4PbBr6')
axs[2].set_xlabel('Grinding time [min]', fontsize=20)
axs[2].set_ylabel('Weight Fraction', fontsize=20)
axs[2].set_ylim(0,0.7)
# axs[2].text(0.5, -0.2, "20 [N], 120 [rpm]", ha='center', va='top', transform=axs[0].transAxes, fontsize=20,fontweight="bold")

# Second subplot
axs[1].plot(time, CsBr_10N_speed05[1:], marker='o', label='CsBr')
axs[1].plot(time, PbBr2_10N_speed05[1:], marker='o', label='PbBr2')
axs[1].plot(time, CsPbBr3_10N_speed05[1:], marker='o', label='CsPbBr3')
axs[1].plot(time, Cs4PbBr6_10N_speed05[1:], marker='o', label='Cs4PbBr6')
axs[1].set_xlabel('Grinding time [min]', fontsize=20)
axs[1].set_ylabel('Weight Fraction', fontsize=20)
axs[1].set_ylim(0,0.7)
# axs[1].text(0.5, -0.2, "10 [N], 120 [rpm]", ha='center', va='top', transform=axs[1].transAxes, fontsize=20,fontweight="bold")

# Third subplot
axs[0].plot(time, CsBr_20N_speed05[1:], marker='o', label='CsBr')
axs[0].plot(time, PbBr2_20N_speed05[1:], marker='o', label='PbBr2')
axs[0].plot(time, CsPbBr3_20N_speed05[1:], marker='o', label='CsPbBr3')
axs[0].plot(time, Cs4PbBr6_20N_speed05[1:], marker='o', label='Cs4PbBr6')
axs[0].set_xlabel('Grinding time [min]', fontsize=20)
axs[0].set_ylabel('Weight Fraction', fontsize=20)
axs[0].set_ylim(0,0.7)
# axs[0].text(0.5, -0.2, "10 [N], 60 [rpm]", ha='center', va='top', transform=axs[2].transAxes, fontsize=20,fontweight="bold")

plt.rcParams["font.size"] = 20
plt.tight_layout()
plt.legend(loc="upper right",fontsize=14)
plt.savefig('result2_and_3.png', dpi=300)
